# %% [markdown]
# >> ### **9주차 ~ 11주차 실습**
# >>> #### 형태소 추출하고 감성분석(Sentiment analysis)
# <img src = 'https://images.unsplash.com/photo-1598518619776-eae3f8a34eac?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8NHx8a3VuZ2Z1fGVufDB8fDB8fHww&auto=format&fit=crop&w=500&q=60'>

# %% [markdown]
# > ### **1. 텍스트 수집(빅카인즈)**
# - https://m.blog.naver.com/j7youngh/222966330839(요기를 참조하여 코드 작성하였음)

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/GEPS.xlsx')
df.shape
# Out:
# (4204, 19)

# %%
df.columns
# Out:
# Index(['뉴스 식별자', '일자', '언론사', '기고자', '제목', '통합 분류1', '통합 분류2', '통합 분류3',
#        '사건/사고 분류1', '사건/사고 분류2', '사건/사고 분류3', '인물', '위치', '기관', '키워드',
#        '특성추출(가중치순 상위 50개)', '본문', 'URL', '분석제외 여부'],
#       dtype='object')

# %%
df.head()
# Out:
#          뉴스 식별자        일자     언론사                      기고자  \
# 0  1.100801e+06  20221230    조선일보                   김석모 기자
# 1  2.100311e+06  20221229    서울경제                   김민경 기자
# 2  2.100501e+06  20221228  파이낸셜뉴스  강구귀 기자 (ggg@fnnews.com)
# 3  2.100851e+06  20221228    아주경제                      전성민
# 4  1.100301e+06  20221228    내일신문     김영숙 기자 kys@naeil.com
#
#                                          제목    통합 분류1      통합 분류2      통합 분류3  \
# 0            충남 교직원 관사 예산 삭감 道교육청 “교사복지 외면”     지역>충남       지역>전북       지역>경기
# 1                [시그널] 민낯 드러난 ESG채권 발행량 반토막  경제>산업_기업   경제>금융_재테크    경제>증권_증시
# 2                    공무원연금, ESG투자 성과보상체계 개편  경제>증권_증시   경제>금융_재테크       경제>무역
# 3      인형극으로 느끼는 환경의 중요성...예술위, '모두의 바다' 공연     지역>충남       지역>대전       지역>울산
# 4  서원주 신임 CIO(국민연금 기금운용본부장) '기업 지배구조 개선' 강조  정치>행정_자치    경제>산업_기업   경제>금융_재테크
#
#   사건/사고 분류1 사건/사고 분류2 사건/사고 분류3           인물  \
# 0       NaN       NaN       NaN          최광희
# 1       NaN       NaN       NaN          NaN
# 2       NaN       NaN       NaN          NaN
# 3       NaN       NaN       NaN  박종관,배준열,송재식
# 4       NaN       NaN       NaN        김태현,서
#
#                                      위치  \
# 0    삽교읍,목리,최창용,충남,호도,예산군,내포신도시,관사도,충남도
# 1                           방산,우크라이나,회계
# 2                               제주,혁신도시
# 3                            전남,광주지부,광주
# 4  서울,서원주,서대문구,부산,뉴욕,대주주,최고경영자(,싱가포르,임하
#
#                                                   기관  \
# 0  도의회,교육,충남,충남도교육청,충남교육청,예산결산특별위원회,충남도의회,교육위,예결특...
# 1  공무원연금공단,한국거래소,국민연,SK텔레콤,러시아 전쟁,펀드평가사,코리안리,ESG채...
# 2           공무원연금공단,공무원연금기금 책임투자 강화방안,ESG,공무원연금,투자은행
# 3  한국환경공단 광주전남제주환경본부,굿네이버스 광주전남지역본부,공무원연금공단,한국문화예...
# 4  경영학과,공무원연금공단,보건복지부,기금이사추천위원회,국민연,신한금융지주,기금운용본부...
#
#                                                  키워드  \
# 0  삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1  민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2  공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3  인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4  CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1   esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2  esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3  인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4  국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
#
#                                                   본문  \
# 0  충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1  지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2  제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3  시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4  900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...
#
#                                                  URL 분석제외 여부
# 0  https://www.chosun.com/national/regional/chung...     NaN
# 1         http://www.sedaily.com/NewsView/26F3B97C1J     NaN
# 2      http://www.fnnews.com/news/202212281916520843     NaN
# 3     https://www.ajunews.com/view/20221228164416372     NaN
# 4      http://www.naeil.com/news_view/?id_art=446514     NaN

# %%
col = ['일자', '언론사', '통합 분류1', '통합 분류2', '통합 분류3', '키워드', '특성추출(가중치순 상위 50개)', '본문']
df = pd.read_excel("GEPS.xlsx", usecols = col)
df.head()
# Out:
#          일자     언론사    통합 분류1      통합 분류2      통합 분류3  \
# 0  20221230    조선일보     지역>충남       지역>전북       지역>경기
# 1  20221229    서울경제  경제>산업_기업   경제>금융_재테크    경제>증권_증시
# 2  20221228  파이낸셜뉴스  경제>증권_증시   경제>금융_재테크       경제>무역
# 3  20221228    아주경제     지역>충남       지역>대전       지역>울산
# 4  20221228    내일신문  정치>행정_자치    경제>산업_기업   경제>금융_재테크
#
#                                                  키워드  \
# 0  삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1  민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2  공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3  인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4  CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1   esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2  esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3  인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4  국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
#
#                                                   본문
# 0  충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1  지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2  제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3  시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4  900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...

# %%
df['년도'] = df['일자']//10000
df
# Out:
#             일자     언론사     통합 분류1      통합 분류2      통합 분류3  \
# 0     20221230    조선일보      지역>충남       지역>전북       지역>경기
# 1     20221229    서울경제   경제>산업_기업   경제>금융_재테크    경제>증권_증시
# 2     20221228  파이낸셜뉴스   경제>증권_증시   경제>금융_재테크       경제>무역
# 3     20221228    아주경제      지역>충남       지역>대전       지역>울산
# 4     20221228    내일신문   정치>행정_자치    경제>산업_기업   경제>금융_재테크
# ...        ...     ...        ...         ...         ...
# 4199  20160104    전자신문      지역>경남       지역>부산       지역>충북
# 4200  20160104    전자신문      지역>부산       지역>경남       지역>충북
# 4201  20160104    제민일보  경제>금융_재테크   경제>서비스_쇼핑       경제>유통
# 4202  20160103   머니투데이  경제>금융_재테크       경제>유통   경제>서비스_쇼핑
# 4203  20160101    광주일보   사회>사건_사고      사회>장애인       사회>여성
#
#                                                     키워드  \
# 0     삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1     민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2     공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3     인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4     CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
# ...                                                 ...
# 4199  공무원연금관리공단,2020년,분담,동결,고통,세대,형평,보완,차원,양해,공무원연금관...
# 4200  공무원연금관리공단,2020년,연금,동결,공무원연금관리공단,출처,공무원,연금,관리,공...
# 4201  공무원,연금,안심,통장,일제,출시,연금법,개정,150만,원이하,압류,설정,농협,제주...
# 4202  은행권,공무원연금,출시,안심,통장,일제,공무원연금,압류,방지,통장,출시,은행별,유치...
# 4203  희망,감전사고,재활중,노석훈,소방관,차례,수술,광주,재기,희망,아이콘,번째,번째,아...
#
#                                       특성추출(가중치순 상위 50개)  \
# 0     교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1      esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2     esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3     인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4     국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
# ...                                                 ...
# 4199  공무원,홈페이지,연금법,공무원연금관리공단,전년도,연금액,공무원연금법,임용자,소비자,...
# 4200  공무원,홈페이지,전년도,연금법,연금액,공무원연금법,공무원연금관리공단,임용자,소비자,...
# 4201  수수료,공무원,제주은행,국민연금,150만,개정안,전자금융,연금법,공무원연금평생안심통...
# 4202  공무원,수수료,만큼,압류금지,150만,공무원연금평생안심통장,개정안,최저생계비,자동화...
# 4203  소방장,소방관,벌집,전신주,광주,광주시,교육훈련,시민들,24차례,한전병원,의료진,서...
#
#                                                      본문    년도
# 0     충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...  2022
# 1     지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...  2022
# 2     제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...  2022
# 3     시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...  2022
# 4     900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...  2022
# ...                                                 ...   ...
# 4199  공무원연금관리공단\n출처:/공무원연금관리공단 홈페이지 캡처\n \n \n공무원연금관...  2016
# 4200  공무원연금관리공단\n출처:/ 공무원연금관리공단 홈페이지 \n \n공무원연금관리공단 ...  2016
# 4201  연금법 개정 맞춰 150만원이하, 압류금지 설정 \n\n농협.제주은행 등 우대 혜택...  2016
# 4202  공무원연금의 압류를 방지하기 위한 통장이 출시된다. 은행별로 유치 경쟁이 치열할 것...  2016
# 4203  “죽지 않고 살아난 게 첫 번째 행운, 한 손만 잃은 게 두 번째 행운, 아내를 만...  2016
#
# [4204 rows x 9 columns]

# %% [markdown]
# > ## **2. konlpy, Mecab을 이용한 토큰화**
# >> 한글 토큰화 도구로 koNLPy에 제공하는 Mecab을 사용하면 가장 정확하게 형태소 분석을 할 수 있다. Mecab은 설치 과정이 다른 형태소 분류기보다 복잡하지만 형태소 분류 성능과 속도가 가장 뛰어난 것으로 알려져 있다.
# >>> <font color='blue'> Mecab가 설치가 안되니 Hanmaum으로 했다

# %%
# 한글 자연어 처리기 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 43.3 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 41.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %% [markdown]
# ### 감성어 분석을 하기 위해서는 명사보다는 형태소를 토큰화하는 것이 타당하다.
# - 토픽 분석과 같이 객관적인 단어가 필요할 때는 명사를, 감성분석과 같이 감성이 표현된 단어가 필요할 때는 형태소 분석이나 스페이스로 토큰화해 형용사나 동사의 형태를 살리는 것이 감성을 추출하는데 한층 유용하다.
# - 한글 감성어 사전에 있는 단어와 리뷰 각 문장에 들어있는 토큰화된 단어와 비교하여 극성값을 평가해야 한다. 이를 위해 우선 KNU 감성어 사전을 코랩에 업로드

# %%
# 한글 형태소 분석기인 Mecab 설치
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)

# %% [markdown]
# >> ### 온라인 기사 본문의 내용을 형태소로 변경하는 작업이 필요
# - 데이터 중에서 본문만 필요하니까 요기만 추출

# %%
reviews = df['본문']
reviews
# Out:
# 0       충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1       지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2       제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3       시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4       900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...
#                               ...
# 4199    공무원연금관리공단\n출처:/공무원연금관리공단 홈페이지 캡처\n \n \n공무원연금관...
# 4200    공무원연금관리공단\n출처:/ 공무원연금관리공단 홈페이지 \n \n공무원연금관리공단 ...
# 4201    연금법 개정 맞춰 150만원이하, 압류금지 설정 \n\n농협.제주은행 등 우대 혜택...
# 4202    공무원연금의 압류를 방지하기 위한 통장이 출시된다. 은행별로 유치 경쟁이 치열할 것...
# 4203    “죽지 않고 살아난 게 첫 번째 행운, 한 손만 잃은 게 두 번째 행운, 아내를 만...
# Name: 본문, Length: 4204, dtype: object

# %% [markdown]
# >> #### 형태소를 추출하는 라이브러리가 많은데 그 중에 하나를 임의 선택, 어떤게 좋은지는 모르겠음

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum() # twitter()

# %%
print(hannanum.morphs(u'롯데마트의 흑마늘 양념 치킨이 논란이 되고 있다.'))
# Out:
# ['롯데마트', '의', '흑마늘', '양념', '치킨', '이', '논란', '이', '되', '고', '있', '다', '.']

# %%
reviews[:2]
# Out:
# 0    충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1    지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# Name: 본문, dtype: object

# %%
for i in reviews[:2]:
    print(hannanum.morphs(i))
# Out:
# ['충남', '의', '교직원들', '을', '위하', 'ㄴ', '관사', '신축', '매입', '사업', '예산', '이', '충남도의회', '에서', '전액', '삭감', '되', '면서', '논란', '이', '일', '고', '있', '다', '.', '원거리', '출퇴근', '하', '는', '교직원들', '이', '쓰', 'ㄹ', '관사', '확보', '에', '필요', '하', 'ㄴ', '내년', '예산', '이', '도의회', '예산', '심사', '과정', '에서', '모두', '사라지', '자', '교직원', '반발', '이', '크', '어', '지', '고', '있', '는', '것', '이', '다', '.', '충남교육청', '은', '“시', '굴', 'ㄴ', '단위', '로', '전보', '가', '잦', '은', '교직원들', '에게', '관사', '는', '반드시', '필요하다”고', '주장', '하', '는', '반면', ',', '도의회', '는', '“경찰', '..']
# ['지난해', '국내', '기업들', '의', '자금', '조달', '창구', '로', '주목', '받', '아ㄴ', '환경', '사회', '지배구조(ESG)', '회사채', '발행', '이', '올해', '는', '크', '게', '줄', '어', '든', '것', '으로', '나타나', '아다', '.', '시장금리', '가', '가파르', '게', '상승', '하', '면서', '채권', '투', '이', '자', '수요', '가', '감소', '하', 'ㄴ', '영향', '이', '크', 'ㄴ', '것', '으로', '보이', '며', ',', '국민연금', '등', '‘큰손’들로부터', '관심', '을', '받', '지', '못하', '자', '여러', '기업', '이', 'ESG', '꼬리표', '를', '떼', '고', '일반', '회사채', '로', '눈', '을', '돌리', 'ㄴ', '것', '도', '원인', '으로', '꼽히', 'ㄴ다', '.', '..']

# %%
t = [hannanum.morphs(i) for i in reviews[:2]]
len(t)
# Out:
# 2

# %%
tokens = [hannanum.morphs(word) for word in reviews]

# %%
len(tokens)
# Out:
# 4204

# %%
tokens[:1]

# %%
tokens = list(map(lambda x : " ".join(x), tokens))

# %%
tokens[:10]
# Out:
# ['충남 의 교직원들 을 위하 ㄴ 관사 신축 매입 사업 예산 이 충남도의회 에서 전액 삭감 되 면서 논란 이 일 고 있 다 . 원거리 출퇴근 하 는 교직원들 이 쓰 ㄹ 관사 확보 에 필요 하 ㄴ 내년 예산 이 도의회 예산 심사 과정 에서 모두 사라지 자 교직원 반발 이 크 어 지 고 있 는 것 이 다 . 충남교육청 은 “시 굴 ㄴ 단위 로 전보 가 잦 은 교직원들 에게 관사 는 반드시 필요하다”고 주장 하 는 반면 , 도의회 는 “경찰 ..',
#  '지난해 국내 기업들 의 자금 조달 창구 로 주목 받 아ㄴ 환경 사회 지배구조(ESG) 회사채 발행 이 올해 는 크 게 줄 어 든 것 으로 나타나 아다 . 시장금리 가 가파르 게 상승 하 면서 채권 투 이 자 수요 가 감소 하 ㄴ 영향 이 크 ㄴ 것 으로 보이 며 , 국민연금 등 ‘큰손’들로부터 관심 을 받 지 못하 자 여러 기업 이 ESG 꼬리표 를 떼 고 일반 회사채 로 눈 을 돌리 ㄴ 것 도 원인 으로 꼽히 ㄴ다 . ..',
#  '제주 혁신도시 공무원연금공단 [ 파이낸셜뉴스 ] 공무원연금공단 이 환경 사회 지배구조(ESG) 투자노력 및 성과 에 대하 ㄴ 평가 를 반영해서 금융자산 운용 성과보상체계 를 개편 하 ㄴ다 . 국내 연기금 최초 이 다 . 28일 투자은행(IB) 업계 에 따르 면 공무원연금 은 ESG 평가 를 반영해 금융자산 운용 성과보상체계 개편 을 단행 하 었다 . ESG 투자노력 및 성 과는 연도별 ..',
#  '시민 자원봉사자 가 환경인형극 ‘모두 의 바다’ 실연 하 는 모습 [사진 = 한국문화예술위원회 ] 인형극 이 환경 의 중요성 을 아이들의\xa0마음속으로\xa0전했다 . 한국문화예술위원회(위원장 박종관) 는 28일 “한국환경공단\xa0광주전남제주환경본부(본부장 송재식 ), 굿네이버스\xa0광주전남지역본부(본부장 배준열)과\xa0함께 환경인형극 ‘모두 의 바다’ 공연 을 진행했다”라 이 고 전했 ..',
#  "900조원 에 달하 는 국민연금 기금 을 운용 하 게 되 ㄴ 서원주 신 이 ㅁ 국민연금 기금운용본부장(CIO) 이 취 이 ㅁ 일 성 으로 ' 기업 지배구조 개선 ' 을 강조 하 었다 . 서 어 신 이 ㅁ 본부장 은 서 ㄴ 한 청지기 의 의무 를 다하 기 위하 어 스튜어드십 코드 강화 에 최선 을 노력 을 다하 겠다며 국민연금 이 대주주 로 있 는 주요 소유분산기업 의 지배구조 투명성 강화 와 CEO 연 이 ㅁ 등 에 적극 개입 하 ㄹ 의사 를 나 아 타 아 ..",
#  '[헤럴드경제=김상훈 기 이 자 ] 공무원연금공단 은 ESG ( 환경 사회 지배구조 ) 투 이 자 촉진 및 수익률 제고 를 위하 어 국내 연기금 최초 로 ESG 투자노력 및 성과 에 대하 ㄴ 평가 를 반영해 금융자산 운용 성과보상체계 를 개편 하 었다 고 28일 밝히 었다 . ESG투자노력 및 성 과는 연도별 책임투자비중 과 BM초과수익률 달성여부 로 평가 하 며 , ESG투 이 자 확대 및 ESG투자 에 따르 ㄴ ..',
#  '국민연금공단 신 이 ㅁ 기금이사(기금운용본부장 CIO ) 로 임명 되 ㄴ 서원주 전 공무원연금공단 자금운용단장(57 사 아 지 ㄴ ) 이 KT 와 포스코 등 지분 이 여러 곳 으로 분산 되 ㄴ 기업들 의 최고경영자(CEO) 선 이 ㅁ 관행 에 경고 메시지 를 내 었다 . 기금운용본부장 은 949조 원(작년 말 ㄹ 기준 ) 에 이르 는 국민 의 노후 자산 을 굴 ㄹ 리 이 며 국내외 산업계 와 금융시장 에 막강한 영향력 을 행사 하 기 때문 ..',
#  '서원주(57) 신 이 ㅁ 국민연금공단 기금운용본부장 은 27 이 ㄹ “국민연금 이 지속적 으로 추진 하 는 수탁자 책임투자 활동 의 일환 으로 투 이 자 기업 의 합리적 이 ㄴ 지배 구조 와 관련 되 ㄴ 주주권 을 행사하겠다”고 말 하 었다 . 서 어 본부장 은 이날 임명 되 ㄴ 직후 국민연금공단 에서 기 이 자 간담회 를 갖 고 “(특정 대주주 가 없 고 ) 소유 가 분산 되 ㄴ 기업들 의 CEO ( 최고경영자 ) 는 객관적 이 고 합리적 이 며 ..',
#  '900조원 국민연금 기금 운용 을 책임지 ㄹ 국민연금공단 기금이사(기금운용본부장) 에 서원주(57 사 아 지 ㄴ ) 전 공무원연금공단 자금운용단장 이 27일 임명 되 었다 . 임기 는 2년 이 며 , 직무수행 실적 에 따르 아 1년 단위 로 연 이 ㅁ 이 가능 하 다 . 서 어 이사 는 삼성생명보험 에서 자산운용 및 투자경력 을 쌓 은 뒤 PCA생명보험(현 미래에셋생명) 자산운용본부장 을 거치 어 2019 2022년 공무 ..',
#  '서원주 전 공무원연금공단 자금운용본부장(57) 이 국민연금공단 신 이 ㅁ 기금이사 에 선임 되 었다 . 국민연금공단 은 27일 신 이 ㅁ 기금이사 로 서원주(57) 씨 를 임명 하 었다 고 밝히 었다 . 서 어 신 이 ㅁ 이사 의 임기 는 오 는 2024년 12월 26일 까지 2년 이 며 , 실적 에 따르 아 1년 단위 연 이 ㅁ 이 가능 하 다 . 서 어 이사 는 지나 ㄴ 1988년 부터 약 26년 가 ㄴ 삼성생명보험 에서 자 . .']

# %% [markdown]
# 서울대 꼬꼬마 -- 이거 괜찮은 듯
#
# '''
#
# from konlpy.tag import Kkma
#
# kkma = Kkma()   # 객체화
#
# print(kkma.morphs(u'공부를 하면할수록 모르는게 많다는 것을 알게 됩니다.'))
# >>> ['공부', '를', '하', '면', '하', 'ㄹ수록', '모르', '는', '것', '이', '많', '다는', '것', '을', '알', '게', '되', 'ㅂ니다', '.']
#
# print(kkma.nouns(u'대학에서 DB, 통계학, 이산수학 등을 배웠지만...'))
# >>> ['대학', '통계학', '이산', '이산수학', '수학', '등']
#
# print(kkma.pos(u'다 까먹어버렸네요?ㅋㅋ'))
# >>> [('다', 'MAG'), ('까먹', 'VV'), ('어', 'ECD'), ('버리', 'VXV'), ('었', 'EPT'), ('네요', 'EFN'), ('?', 'SF'), ('ㅋㅋ', 'EMO')]
#
# print(kkma.sentences(u'그래도 계속 공부합니다. 재밌으니까!'))
# >>> ['그래도 계속 공부합니다.', '재밌으니까!']
#
# '''

# %% [markdown]
# >> ###### KNU 감성어 사전은 json 파일로 만들어져 있음으로 json 라이브러리를  호출해 사전 파일 SentiWord_info.json을 열고, 영화리뷰와 비교할 수 있도록 데이터프레임으로 만들도록 하자.
# - 감성어 사전 링크:
#
# https://github.com/park1200656/KnuSentiLex/tree/master/KnuSentiLex/data

# %%
import json

with open('SentiWord_info.json', encoding='utf-8-sig', mode='r') as f:
  SentiWord_info = json.load(f)

sentiword_dic = pd.DataFrame(SentiWord_info)

# %%
sentiword_dic
# Out:
#          word word_root polarity
# 0         (-;         (        1
# 1       (;_;)     (;_;)       -1
# 2        (^^)      (^^)        1
# 3       (^-^)     (^-^)        1
# 4        (^^*         (        1
# ...       ...       ...      ...
# 14849  반신반의하다      반신반의        0
# 14850    신비롭다        신비        1
# 14851   아리송하다       아리송       -1
# 14852    알쏭하다       알쏭하       -1
# 14853  알쏭달쏭하다      알쏭달쏭       -1
#
# [14854 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(sentiword_dic, *['polarity'], **{})
# chart

# %% [markdown]
# > ## **3. 토큰화된 문장과 감성사전 비교**
# - 이제 영화 리뷰 한 문장씩을 넣어서 해당 문장에 있는 단어와 감성사전 단어를 매치시켜 존재하면 극성값을 가져오고, 없으면 패스시키도록 하자.
# - 이때 문장 하나를 가져와 단어를 하나씩 끄집어 넣어 감성 사전 단어와 비교해야 하기 때문에 2중  for 문을 이용해야 한다.
# - 리뷰 문장별 극성값은 문장의 포함된 단어의 극성값 합계로 계산한다. 예를 들어, "나는 이 영화가 재밌고 감동적이다"라면, '재밌고'가 +1, 감동적이다 +2점으로 이 문장은 긍정적인 +3점 리뷰로 판단된다.

# %%
tf = pd.DataFrame(columns=("review", "sentiment"))  # 리뷰별 극성을 저장하기 위한 데이터프레임 생성
tf
# Out:
# Empty DataFrame
# Columns: [review, sentiment]
# Index: []

# %%
from tqdm import tqdm

# %%
from time import time       # 아래 코드가 몇시간 걸리나
time()          # 현재 시간을 알려줌
# Out:
# 1692772089.9195402

# %%
start = time() # 시작시간 기록

idx = 0                                             # 다음 리뷰로 넘기기 위한 초기값

for token in tqdm(tokens):                                # 전체 리뷰에서 문장 하나씩 가져옴
  sentiment = 0                                     # 초기 감성값 0으로 설정
  for i in range(0, len(sentiword_dic)):            # 감성사전의 모든 단어를 하나씩 선택
    if sentiword_dic.word[i] in token:              # 리뷰 문장에 감성 단어가 있는지 확인
      sentiment += int(sentiword_dic.polarity[i])   # 감성단어가 있다면 극성값 합계를 구함.
  tf.loc[idx] = [token, sentiment]                  # 리뷰별 극성값을 데이터프레임으로 쌓음
  idx += 1                                          # 다름 리뷰 문장으로 넘어감

end = time()  # 끝나는 시간 기록

print(f'time elapsed: {end - start}')
# Out:
# 100%|██████████| 4204/4204 [13:03<00:00,  5.36it/s]
# time elapsed: 783.762687921524

# %%
tf
# Out:
#                                                  review  sentiment
# 0     [충남, 의, 교직원들, 을, 위하, ㄴ, 관사, 신축, 매입, 사업, 예산, 이,...          0
# 1     [지난해, 국내, 기업들, 의, 자금, 조달, 창구, 로, 주목, 받, 아ㄴ, 환경...          0
# 2     [제주, 혁신도시, 공무원연금공단, [, 파이낸셜뉴스, ], 공무원연금공단, 이, ...          0
# 3     [시민, 자원봉사자, 가, 환경인형극, ‘모두, 의, 바다’, 실연, 하, 는, 모...          0
# 4     [900조원, 에, 달하, 는, 국민연금, 기금, 을, 운용, 하, 게, 되, ㄴ,...          3
# ...                                                 ...        ...
# 4199  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 캡처, 공무원연금...         -1
# 4200  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 공무원연금관리공단...         -1
# 4201  [연금법, 개정, 맞추, 어, 150만원, 이하, ,, 압류금지, 설정, 농협, ....          1
# 4202  [공무원연금, 의, 압류, 를, 방지, 하, 기, 위하, ㄴ, 통장, 이, 출시, ...          0
# 4203  [“죽지, 않, 고, 살, 아, 나, ㄴ, 것, 이, 첫, 번, 째, 행운, ,, ...          1
#
# [4204 rows x 2 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['review'],)"
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(tf, *['sentiment'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(tf, *['sentiment'], **{})
# chart

# %%
tf.to_excel('tf01.xlsx')

# %%
tf.to_pickle('tf01.pkl')

# %%
gf = pd.read_pickle('tf01.pkl')
gf
# Out:
#                                                  review  sentiment
# 0     [충남, 의, 교직원들, 을, 위하, ㄴ, 관사, 신축, 매입, 사업, 예산, 이,...          0
# 1     [지난해, 국내, 기업들, 의, 자금, 조달, 창구, 로, 주목, 받, 아ㄴ, 환경...          0
# 2     [제주, 혁신도시, 공무원연금공단, [, 파이낸셜뉴스, ], 공무원연금공단, 이, ...          0
# 3     [시민, 자원봉사자, 가, 환경인형극, ‘모두, 의, 바다’, 실연, 하, 는, 모...          0
# 4     [900조원, 에, 달하, 는, 국민연금, 기금, 을, 운용, 하, 게, 되, ㄴ,...          3
# ...                                                 ...        ...
# 4199  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 캡처, 공무원연금...         -1
# 4200  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 공무원연금관리공단...         -1
# 4201  [연금법, 개정, 맞추, 어, 150만원, 이하, ,, 압류금지, 설정, 농협, ....          1
# 4202  [공무원연금, 의, 압류, 를, 방지, 하, 기, 위하, ㄴ, 통장, 이, 출시, ...          0
# 4203  [“죽지, 않, 고, 살, 아, 나, ㄴ, 것, 이, 첫, 번, 째, 행운, ,, ...          1
#
# [4204 rows x 2 columns]

# %% [markdown]
# > # <font color='blue'>**알면 좋은 것들**
# >> #### **1. 모듈과 라이브러리, 메서드**

# %%
1 + 3
# Out:
# 4

# %%
a = 3
b = 5
c = a + b
print(c)
# Out:
# 8

# %%
def my_add(a, b):
    print("Hello  두 수자를 입력하면 더해줄게 ")
    c = a + b
    return c

# %%
my_add(3,4)
# Out:
# 7

# %%
# %%writefile sanggoo.py

def my_add(a, b):
    print("Hello  두 수자를 입력하면 더해줄게 ")
    c = a + b
    return c
# Out:
# Writing sanggoo.py

# %% [markdown]
# #### 방법 1

# %%
import sanggoo

# %%
sanggoo.my_add(3, 4)
# Out:
# Hello  두 수자를 입력하면 더해줄게
# 7

# %%
sanggoo.my_add(2,3)
# Out:
# Hello  두 수자를 입력하면 더해줄게
# 5

# %% [markdown]
# 방법 2

# %%
from sanggoo import my_add

# %%
my_add(5,10)
# Out:
# Hello  두 수자를 입력하면 더해줄게
# 15

# %% [markdown]
# >> #### **2. 데이터프레임을 엑셀로 다운받기**

# %%
tf.head()
# Out:
#                                               review  sentiment
# 0  충남 의 교직원들 을 위하 ㄴ 관사 신축 매입 사업 예산 이 충남도의회 에서 전액 ...          0
# 1  지난해 국내 기업들 의 자금 조달 창구 로 주목 받 아ㄴ 환경 사회 지배구조(ESG...         -2
# 2  제주 혁신도시 공무원연금공단 [ 파이낸셜뉴스 ] 공무원연금공단 이 환경 사회 지배구...          1
# 3  시민 자원봉사자 가 환경인형극 ‘모두 의 바다’ 실연 하 는 모습 [사진 = 한국문...         -1
# 4  900조원 에 달하 는 국민연금 기금 을 운용 하 게 되 ㄴ 서원주 신 이 ㅁ 국민...          4

# %%
tf.to_excel('tf.xlsx')

# %% [markdown]
# >> #### **3. 여러 파일(엑셀, 데이터프레임)을 하나의 파일로 합치기(200개)**
# - 공공기관명

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import glob
glob.glob('*.xlsx')
# Out:
# ['tf.xlsx', 'GEPS.xlsx']

# %%
for i in glob.glob('*.xlsx'):
    pd.read_excel(i).head(2)   # pd.read_excel(i, sheet_name= None) 파일내 모든 시트 읽기

# %%
glob.glob('*.xls')
# Out:
# ['대구점.xls', '대전점.xls']

# %%
for i in glob.glob('*.xls'):
    print(i)
    pd.read_excel(i).head(2)
# Out:
# 대구점.xls
#       일시     고객번호  Item No  판매량   단가  할인율    매출액 결재방법   비고
# 0  42737  2013010        5    7   50  0.1  315.0   카드  NaN
# 1  42737  2013010       16    3  105  0.0  315.0   카드  NaN
# 대전점.xls
#       일시     고객번호  Item No  판매량  단가   할인율     매출액 결재방법   비고
# 0  42737  2009012        3    3  21  0.00   63.00   현금  NaN
# 1  42737  2009012       11    7  32  0.03  217.28   현금  NaN

# %%
# 빈 데이터프레임을 만들고 합친다
sf = pd.DataFrame()

for i in glob.glob('*.xls'):
    print(i)
    data = pd.read_excel(i) # 파이썬의 판다로 데이터프레임
    data['공공기관'] = str(i)
    sf = sf.append(data)
# Out:
# 대구점.xls
# 대전점.xls
# <ipython-input-67-944230739d68>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sf = sf.append(data)
# <ipython-input-67-944230739d68>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sf = sf.append(data)

# %%
sf
# Out:
#        일시     고객번호  Item No       판매량   단가   할인율           매출액 결재방법    비고
# 0   42737  2013010        5         7   50  0.10  3.150000e+02   카드   NaN
# 1   42737  2013010       16         3  105  0.00  3.150000e+02   카드   NaN
# 2   42737  2013010        7         2    5  0.00  1.000000e+01   카드  거래취소
# 3   42737  2013010       15         3  110  0.00  3.300000e+02   카드   NaN
# 4   42737  2013010       24         3   10  0.00  3.000000e+01   카드   NaN
# 5   42737  2013010       19         3   14  0.00  4.200000e+01   카드   NaN
# 6   42737  2013010       16         1  105  0.00  1.050000e+02   카드   NaN
# 7   42737  2013010       20         1   16  0.00  1.600000e+01   현금   NaN
# 8   42737  2013010       11         1   32  0.03  3.104000e+01   현금   NaN
# 9   42737  2013010        6         3   12  0.00  3.600000e+01   현금   NaN
# 10  42737  2013010        8         2   33  0.00  6.600000e+01   현금   NaN
# 11  42737  2016026       10         1   65  0.00  6.500000e+01   현금   NaN
# 12  42737  2016026        1         5   10  0.05  4.750000e+01   현금   NaN
# 13  42737  2016026        2         3   15  0.00  4.500000e+01   현금   NaN
# 14  42737  2016026       25         2   25  0.00  5.000000e+01   현금   NaN
# 15  42737  2016025        3         1   21  0.00  2.100000e+01   현금  거래취소
# 16  42737  2016025       24        12   10  0.00  1.200000e+02   현금   NaN
# 17  42737  2016025        5         5   50  0.10  2.250000e+02   현금   NaN
# 18  42737  2016025        5  10000000   50  0.10  5.000000e+08   현금   NaN
# 0   42737  2009012        3         3   21  0.00  6.300000e+01   현금   NaN
# 1   42737  2009012       11         7   32  0.03  2.172800e+02   현금   NaN
# 2   42737  2016623        2         1   15  0.00  1.500000e+01   카드   NaN
# 3   42737  2016623       15         8  110  0.00  8.800000e+02   카드   NaN
# 4   42737  2016623       13         9   53  0.00  4.770000e+02   카드   NaN
# 5   42737  2010002       19         2   14  0.00  2.800000e+01   카드   NaN
# 6   42737  2010002       13         1   53  0.00  5.300000e+01   카드   NaN
# 7   42737  2010002       20         5   16  0.00  8.000000e+01   현금   NaN
# 8   42737  2010002       17         1   65  0.00  6.500000e+01   현금   NaN
# 9   42737  2010030        5         3   50  0.10  1.350000e+02   현금   NaN
# 10  42737  2010030        8         1   33  0.00  3.300000e+01   현금   NaN
# 11  42737  2010030       10         1   65  0.00  6.500000e+01   현금   NaN
# 12  42737  2016013        7         5    5  0.00  2.500000e+01   현금  거래취소
# 13  42737  2016013        5         1   50  0.10  4.500000e+01   현금   NaN

# %% [markdown]
# >> #### **4. 동일기사내용 지우기**

# %%
df
# Out:
#             일자     언론사     통합 분류1      통합 분류2      통합 분류3  \
# 0     20221230    조선일보      지역>충남       지역>전북       지역>경기
# 1     20221229    서울경제   경제>산업_기업   경제>금융_재테크    경제>증권_증시
# 2     20221228  파이낸셜뉴스   경제>증권_증시   경제>금융_재테크       경제>무역
# 3     20221228    아주경제      지역>충남       지역>대전       지역>울산
# 4     20221228    내일신문   정치>행정_자치    경제>산업_기업   경제>금융_재테크
# ...        ...     ...        ...         ...         ...
# 4199  20160104    전자신문      지역>경남       지역>부산       지역>충북
# 4200  20160104    전자신문      지역>부산       지역>경남       지역>충북
# 4201  20160104    제민일보  경제>금융_재테크   경제>서비스_쇼핑       경제>유통
# 4202  20160103   머니투데이  경제>금융_재테크       경제>유통   경제>서비스_쇼핑
# 4203  20160101    광주일보   사회>사건_사고      사회>장애인       사회>여성
#
#                                                     키워드  \
# 0     삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1     민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2     공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3     인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4     CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
# ...                                                 ...
# 4199  공무원연금관리공단,2020년,분담,동결,고통,세대,형평,보완,차원,양해,공무원연금관...
# 4200  공무원연금관리공단,2020년,연금,동결,공무원연금관리공단,출처,공무원,연금,관리,공...
# 4201  공무원,연금,안심,통장,일제,출시,연금법,개정,150만,원이하,압류,설정,농협,제주...
# 4202  은행권,공무원연금,출시,안심,통장,일제,공무원연금,압류,방지,통장,출시,은행별,유치...
# 4203  희망,감전사고,재활중,노석훈,소방관,차례,수술,광주,재기,희망,아이콘,번째,번째,아...
#
#                                       특성추출(가중치순 상위 50개)  \
# 0     교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1      esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2     esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3     인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4     국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
# ...                                                 ...
# 4199  공무원,홈페이지,연금법,공무원연금관리공단,전년도,연금액,공무원연금법,임용자,소비자,...
# 4200  공무원,홈페이지,전년도,연금법,연금액,공무원연금법,공무원연금관리공단,임용자,소비자,...
# 4201  수수료,공무원,제주은행,국민연금,150만,개정안,전자금융,연금법,공무원연금평생안심통...
# 4202  공무원,수수료,만큼,압류금지,150만,공무원연금평생안심통장,개정안,최저생계비,자동화...
# 4203  소방장,소방관,벌집,전신주,광주,광주시,교육훈련,시민들,24차례,한전병원,의료진,서...
#
#                                                      본문
# 0     충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1     지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2     제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3     시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4     900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...
# ...                                                 ...
# 4199  공무원연금관리공단\n출처:/공무원연금관리공단 홈페이지 캡처\n \n \n공무원연금관...
# 4200  공무원연금관리공단\n출처:/ 공무원연금관리공단 홈페이지 \n \n공무원연금관리공단 ...
# 4201  연금법 개정 맞춰 150만원이하, 압류금지 설정 \n\n농협.제주은행 등 우대 혜택...
# 4202  공무원연금의 압류를 방지하기 위한 통장이 출시된다. 은행별로 유치 경쟁이 치열할 것...
# 4203  “죽지 않고 살아난 게 첫 번째 행운, 한 손만 잃은 게 두 번째 행운, 아내를 만...
#
# [4204 rows x 8 columns]

# %%
# 제목이 같은 항목 삭제 및 마지막 레코드만 남김
df_dup = df.drop_duplicates(subset=['일자','언론사', '본문'], keep="last")
df_dup.head()
# Out:
#          일자     언론사    통합 분류1      통합 분류2      통합 분류3  \
# 0  20221230    조선일보     지역>충남       지역>전북       지역>경기
# 1  20221229    서울경제  경제>산업_기업   경제>금융_재테크    경제>증권_증시
# 2  20221228  파이낸셜뉴스  경제>증권_증시   경제>금융_재테크       경제>무역
# 3  20221228    아주경제     지역>충남       지역>대전       지역>울산
# 4  20221228    내일신문  정치>행정_자치    경제>산업_기업   경제>금융_재테크
#
#                                                  키워드  \
# 0  삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1  민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2  공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3  인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4  CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1   esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2  esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3  인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4  국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
#
#                                                   본문
# 0  충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1  지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2  제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3  시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4  900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...

# %%
df_dup.shape
# Out:
# (4180, 8)

# %% [markdown]
# >> **5. 관련 사이트 깃허브**
# - https://github.com/ancestor9?tab=repositories

# %% [markdown]
# >> **6. 날짜를 살리기**

# %%
tf.tail(2)
# Out:
#                                                  review  sentiment
# 4202  [공무원연금, 의, 압류, 를, 방지, 하, 기, 위하, ㄴ, 통장, 이, 출시, ...          0
# 4203  [“죽지, 않, 고, 살, 아, 나, ㄴ, 것, 이, 첫, 번, 째, 행운, ,, ...          1

# %%
df.tail(2)
# Out:
#             일자    언론사     통합 분류1   통합 분류2      통합 분류3  \
# 4202  20160103  머니투데이  경제>금융_재테크    경제>유통   경제>서비스_쇼핑
# 4203  20160101   광주일보   사회>사건_사고   사회>장애인       사회>여성
#
#                                                     키워드  \
# 4202  은행권,공무원연금,출시,안심,통장,일제,공무원연금,압류,방지,통장,출시,은행별,유치...
# 4203  희망,감전사고,재활중,노석훈,소방관,차례,수술,광주,재기,희망,아이콘,번째,번째,아...
#
#                                       특성추출(가중치순 상위 50개)  \
# 4202  공무원,수수료,만큼,압류금지,150만,공무원연금평생안심통장,개정안,최저생계비,자동화...
# 4203  소방장,소방관,벌집,전신주,광주,광주시,교육훈련,시민들,24차례,한전병원,의료진,서...
#
#                                                      본문
# 4202  공무원연금의 압류를 방지하기 위한 통장이 출시된다. 은행별로 유치 경쟁이 치열할 것...
# 4203  “죽지 않고 살아난 게 첫 번째 행운, 한 손만 잃은 게 두 번째 행운, 아내를 만...

# %%
df['일자']
# Out:
# 0       20221230
# 1       20221229
# 2       20221228
# 3       20221228
# 4       20221228
#           ...
# 4199    20160104
# 4200    20160104
# 4201    20160104
# 4202    20160103
# 4203    20160101
# Name: 일자, Length: 4204, dtype: int64

# %%
tf['일자'] = df['일자'].values

# %%
tf
# Out:
#                                                  review  sentiment        일자
# 0     [충남, 의, 교직원들, 을, 위하, ㄴ, 관사, 신축, 매입, 사업, 예산, 이,...          0  20221230
# 1     [지난해, 국내, 기업들, 의, 자금, 조달, 창구, 로, 주목, 받, 아ㄴ, 환경...          0  20221229
# 2     [제주, 혁신도시, 공무원연금공단, [, 파이낸셜뉴스, ], 공무원연금공단, 이, ...          0  20221228
# 3     [시민, 자원봉사자, 가, 환경인형극, ‘모두, 의, 바다’, 실연, 하, 는, 모...          0  20221228
# 4     [900조원, 에, 달하, 는, 국민연금, 기금, 을, 운용, 하, 게, 되, ㄴ,...          3  20221228
# ...                                                 ...        ...       ...
# 4199  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 캡처, 공무원연금...         -1  20160104
# 4200  [공무원연금관리공단, 출처, :/, 공무원연금관리공단, 홈페이지, 공무원연금관리공단...         -1  20160104
# 4201  [연금법, 개정, 맞추, 어, 150만원, 이하, ,, 압류금지, 설정, 농협, ....          1  20160104
# 4202  [공무원연금, 의, 압류, 를, 방지, 하, 기, 위하, ㄴ, 통장, 이, 출시, ...          0  20160103
# 4203  [“죽지, 않, 고, 살, 아, 나, ㄴ, 것, 이, 첫, 번, 째, 행운, ,, ...          1  20160101
#
# [4204 rows x 3 columns]

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4204 entries, 0 to 4203
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     4204 non-null   object
#  1   sentiment  4204 non-null   int64
#  2   일자         4204 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 131.4+ KB

# %%
pd.to_datetime(tf['일자'])
# Out:
# 0      1970-01-01 00:00:00.020221230
# 1      1970-01-01 00:00:00.020221229
# 2      1970-01-01 00:00:00.020221228
# 3      1970-01-01 00:00:00.020221228
# 4      1970-01-01 00:00:00.020221228
#                     ...
# 4199   1970-01-01 00:00:00.020160104
# 4200   1970-01-01 00:00:00.020160104
# 4201   1970-01-01 00:00:00.020160104
# 4202   1970-01-01 00:00:00.020160103
# 4203   1970-01-01 00:00:00.020160101
# Name: 일자, Length: 4204, dtype: datetime64[ns]

# %%
tf['일자'] = tf['일자'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))
tf.head()
# Out:
#                                               review  sentiment         일자
# 0  [충남, 의, 교직원들, 을, 위하, ㄴ, 관사, 신축, 매입, 사업, 예산, 이,...          0 2022-12-30
# 1  [지난해, 국내, 기업들, 의, 자금, 조달, 창구, 로, 주목, 받, 아ㄴ, 환경...          0 2022-12-29
# 2  [제주, 혁신도시, 공무원연금공단, [, 파이낸셜뉴스, ], 공무원연금공단, 이, ...          0 2022-12-28
# 3  [시민, 자원봉사자, 가, 환경인형극, ‘모두, 의, 바다’, 실연, 하, 는, 모...          0 2022-12-28
# 4  [900조원, 에, 달하, 는, 국민연금, 기금, 을, 운용, 하, 게, 되, ㄴ,...          3 2022-12-28

# %%
## 번외게임

import pandas as pd
df = pd.read_excel('GEPS.xlsx')
df['년도'] = df['일자'] //10000 # 정수형태임, # 나누어서 몫만 챙기기
df
# Out:
#             뉴스 식별자        일자     언론사                      기고자  \
# 0     1.100801e+06  20221230    조선일보                   김석모 기자
# 1     2.100311e+06  20221229    서울경제                   김민경 기자
# 2     2.100501e+06  20221228  파이낸셜뉴스  강구귀 기자 (ggg@fnnews.com)
# 3     2.100851e+06  20221228    아주경제                      전성민
# 4     1.100301e+06  20221228    내일신문     김영숙 기자 kys@naeil.com
# ...            ...       ...     ...                      ...
# 4199  7.100501e+06  20160104    전자신문                      이윤지
# 4200  7.100501e+06  20160104    전자신문                      이윤지
# 4201  1.700101e+06  20160104    제민일보                   고 미 기자
# 4202  2.100201e+06  20160103   머니투데이                   김진형|기자
# 4203  1.600301e+06  20160101    광주일보                      김형호
#
#                                                    제목     통합 분류1      통합 분류2  \
# 0                      충남 교직원 관사 예산 삭감 道교육청 “교사복지 외면”      지역>충남       지역>전북
# 1                          [시그널] 민낯 드러난 ESG채권 발행량 반토막   경제>산업_기업   경제>금융_재테크
# 2                              공무원연금, ESG투자 성과보상체계 개편   경제>증권_증시   경제>금융_재테크
# 3                인형극으로 느끼는 환경의 중요성...예술위, '모두의 바다' 공연      지역>충남       지역>대전
# 4            서원주 신임 CIO(국민연금 기금운용본부장) '기업 지배구조 개선' 강조   정치>행정_자치    경제>산업_기업
# ...                                               ...        ...         ...
# 4199  공무원연금관리공단, 2020년까지 동결 '고통 분담과 세대간 형평성 보완 차원' 양해      지역>경남       지역>부산
# 4200                         공무원연금관리공단, 2020년까지 연금 동결      지역>부산       지역>경남
# 4201                             공무원연금 잡아라 안심통장 일제 출시  경제>금융_재테크   경제>서비스_쇼핑
# 4202                      은행권, 공무원연금 잡아라...안심통장 일제 출시  경제>금융_재테크       경제>유통
# 4203               2016 희망을 쏜다 ① 감전사고 딛고 재활중인 노석훈 소방관   사회>사건_사고      사회>장애인
#
#           통합 분류3   사건/사고 분류1 사건/사고 분류2 사건/사고 분류3           인물  \
# 0          지역>경기         NaN       NaN       NaN          최광희
# 1       경제>증권_증시         NaN       NaN       NaN          NaN
# 2          경제>무역         NaN       NaN       NaN          NaN
# 3          지역>울산         NaN       NaN       NaN  박종관,배준열,송재식
# 4      경제>금융_재테크         NaN       NaN       NaN        김태현,서
# ...          ...         ...       ...       ...          ...
# 4199       지역>충북         NaN       NaN       NaN          NaN
# 4200       지역>충북         NaN       NaN       NaN          NaN
# 4201       경제>유통         NaN       NaN       NaN          NaN
# 4202   경제>서비스_쇼핑         NaN       NaN       NaN          NaN
# 4203       사회>여성  사고>산업사고>화재       NaN       NaN    노,노석훈,이민정
#
#                                          위치  \
# 0        삽교읍,목리,최창용,충남,호도,예산군,내포신도시,관사도,충남도
# 1                               방산,우크라이나,회계
# 2                                   제주,혁신도시
# 3                                전남,광주지부,광주
# 4      서울,서원주,서대문구,부산,뉴욕,대주주,최고경영자(,싱가포르,임하
# ...                                     ...
# 4199                                    NaN
# 4200                                    NaN
# 4201                                     상계
# 4202                                  일제,상계
# 4203  감전,광주시소방본부,광주로,광주시,서울,전신,전선,서구,금호동,도심
#
#                                                      기관  \
# 0     도의회,교육,충남,충남도교육청,충남교육청,예산결산특별위원회,충남도의회,교육위,예결특...
# 1     공무원연금공단,한국거래소,국민연,SK텔레콤,러시아 전쟁,펀드평가사,코리안리,ESG채...
# 2              공무원연금공단,공무원연금기금 책임투자 강화방안,ESG,공무원연금,투자은행
# 3     한국환경공단 광주전남제주환경본부,굿네이버스 광주전남지역본부,공무원연금공단,한국문화예...
# 4     경영학과,공무원연금공단,보건복지부,기금이사추천위원회,국민연,신한금융지주,기금운용본부...
# ...                                                 ...
# 4199                             공무원 연금,공무원연금,공무원연금관리공단
# 4200                             공무원 연금,공무원연금,공무원연금관리공단
# 4201  공무원연금공단,공무원연금 잡아,제주,공무원연금,공무원연금평생안심통장,국회,농협.제주...
# 4202  공무원연금공단,씨티,수출입은행,국민은행,공무원연금,공무원연금평생안심통장,국회,공무원...
# 4203                                   공무원연금공단,정부,조선대병원
#
#                                                     키워드  \
# 0     삭감,충남,교직원,관사,예산,교육청,교사,복지,외면,관사,신축,원룸,가구,매입,10...
# 1     민낯,ESG채권,발행량,반토막,12.5조,전년,25조,절반,수준,기업,창구,자금,조...
# 2     공무원연금,개편,ESG,투자,성과,보상,체계,공무원연금공단,제주,혁신,도시,공무원,...
# 3     인형극,환경,예술위,바다,공연,광주,전남지역,대상,아동,환경인형극,시민,자원,봉사자...
# 4     CIO,서원주,신임,국민연금,기금운용본부장,개선,기업,지배,구조,강조,900조,국민...
# ...                                                 ...
# 4199  공무원연금관리공단,2020년,분담,동결,고통,세대,형평,보완,차원,양해,공무원연금관...
# 4200  공무원연금관리공단,2020년,연금,동결,공무원연금관리공단,출처,공무원,연금,관리,공...
# 4201  공무원,연금,안심,통장,일제,출시,연금법,개정,150만,원이하,압류,설정,농협,제주...
# 4202  은행권,공무원연금,출시,안심,통장,일제,공무원연금,압류,방지,통장,출시,은행별,유치...
# 4203  희망,감전사고,재활중,노석훈,소방관,차례,수술,광주,재기,희망,아이콘,번째,번째,아...
#
#                                       특성추출(가중치순 상위 50개)  \
# 0     교직원,충남교육청,교육청,충남,예결특위,충남도의회,도의회,공무원,충남도,예산안,원거...
# 1      esg,회사채,국민연금,녹색채권,수익률,공제회,평가사,에프앤가이드,기업들,연기금,발행량
# 2     esg,성과보상체계,공무원,공무원연금,제주,공무원연금공단,관계자,강화방안,투자노력,...
# 3     인형극,환경인형극,환경보호,한국문화예술위원회,박종관,광주,굿네이버스,광주전남제주환경...
# 4     국민연금,본부장,지배구조,서원주,연기금,금융지주,기금운용본부장,ceo,수탁자,kt,...
# ...                                                 ...
# 4199  공무원,홈페이지,연금법,공무원연금관리공단,전년도,연금액,공무원연금법,임용자,소비자,...
# 4200  공무원,홈페이지,전년도,연금법,연금액,공무원연금법,공무원연금관리공단,임용자,소비자,...
# 4201  수수료,공무원,제주은행,국민연금,150만,개정안,전자금융,연금법,공무원연금평생안심통...
# 4202  공무원,수수료,만큼,압류금지,150만,공무원연금평생안심통장,개정안,최저생계비,자동화...
# 4203  소방장,소방관,벌집,전신주,광주,광주시,교육훈련,시민들,24차례,한전병원,의료진,서...
#
#                                                      본문  \
# 0     충남의 교직원들을 위한 관사 신축 매입 사업 예산이 충남도의회에서 전액 삭감되면서 ...
# 1     지난해 국내 기업들의 자금 조달 창구로 주목 받았던 환경 사회 지배구조(ESG) 회...
# 2     제주 혁신도시 공무원연금공단 \n \n \n[파이낸셜뉴스] 공무원연금공단이 환경 사...
# 3     시민 자원봉사자가 환경인형극 ‘모두의 바다’ 실연하는 모습 [사진=한국문화예술위원회...
# 4     900조원에 달하는 국민연금 기금을 운용하게 된 서원주 신임 국민연금 기금운용본부장...
# ...                                                 ...
# 4199  공무원연금관리공단\n출처:/공무원연금관리공단 홈페이지 캡처\n \n \n공무원연금관...
# 4200  공무원연금관리공단\n출처:/ 공무원연금관리공단 홈페이지 \n \n공무원연금관리공단 ...
# 4201  연금법 개정 맞춰 150만원이하, 압류금지 설정 \n\n농협.제주은행 등 우대 혜택...
# 4202  공무원연금의 압류를 방지하기 위한 통장이 출시된다. 은행별로 유치 경쟁이 치열할 것...
# 4203  “죽지 않고 살아난 게 첫 번째 행운, 한 손만 잃은 게 두 번째 행운, 아내를 만...
#
#                                                     URL 분석제외 여부    년도
# 0     https://www.chosun.com/national/regional/chung...     NaN  2022
# 1            http://www.sedaily.com/NewsView/26F3B97C1J     NaN  2022
# 2         http://www.fnnews.com/news/202212281916520843     NaN  2022
# 3        https://www.ajunews.com/view/20221228164416372     NaN  2022
# 4         http://www.naeil.com/news_view/?id_art=446514     NaN  2022
# ...                                                 ...     ...   ...
# 4199                                                NaN     NaN  2016
# 4200                                                NaN     NaN  2016
# 4201  http://www.jemin.com/news/articleView.html?idx...     NaN  2016
# 4202  http://news.mt.co.kr/view/mtview.php?no=201601...     NaN  2016
# 4203  http://www.kwangju.co.kr/news_view.php?aid=145...     NaN  2016
#
# [4204 rows x 20 columns]

# %%
## 요래
df['일자']//10000
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 4199    2016
# 4200    2016
# 4201    2016
# 4202    2016
# 4203    2016
# Name: 일자, Length: 4204, dtype: int64
