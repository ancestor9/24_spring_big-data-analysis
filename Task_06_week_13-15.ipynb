# %%
import pandas as pd

# %%
url = 'https://www.melon.com/chart/index.htm'

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-5d8f83db45ac> in <cell line: 1>()
# ----> 1 pd.read_html(url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1203     io = stringify_path(io)
#    1204
# -> 1205     return _parse(
#    1206         flavor=flavor,
#    1207         io=io,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     984
#     985         try:
# --> 986             tables = p.parse_tables()
#     987         except ValueError as caught:
#     988             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in parse_tables(self)
#     260         list of parsed (header, body, footer) tuples from tables.
#     261         """
# --> 262         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     263         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     264
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _build_doc(self)
#     819                     pass
#     820             else:
# --> 821                 raise e
#     822         else:
#     823             if not hasattr(r, "text_content"):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _build_doc(self)
#     800         try:
#     801             if is_url(self.io):
# --> 802                 with urlopen(self.io) as f:
#     803                     r = parse(f, parser=parser)
#     804             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     263     import urllib.request
#     264
# --> 265     return urllib.request.urlopen(*args, **kwargs)
#     266
#     267
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 406: Not Acceptable

# %%
import pandas as pd
import requests

url = 'https://www.melon.com/chart/index.htm'

# Define custom headers to mimic a web browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# Send an HTTP GET request with custom headers
response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML table data using pd.read_html()
    tables = pd.read_html(response.text)
    # Now, 'tables' should contain the data tables from the web page
    display(tables)
else:
    print(f"Failed to fetch the URL. Status code: {response.status_code}")
# Out:
# [    Unnamed: 0    순위      순위등락  앨범이미지 곡 상세가기  \
#  0          NaN    1위  순위 동일  0    NaN    곡정보
#  1          NaN    2위  순위 동일  0    NaN    곡정보
#  2          NaN    3위  단계 상승  1    NaN    곡정보
#  3          NaN    4위  단계 상승  2    NaN    곡정보
#  4          NaN    5위  단계 상승  3    NaN    곡정보
#  ..         ...   ...       ...    ...    ...
#  95         NaN   96위     순위 진입    NaN    곡정보
#  96         NaN   97위  단계 하락  6    NaN    곡정보
#  97         NaN   98위     순위 진입    NaN    곡정보
#  98         NaN   99위  단계 하락  7    NaN    곡정보
#  99         NaN  100위     순위 진입    NaN    곡정보
#
#                                                    곡정보  \
#  0                   Perfect Night  LE SSERAFIM (르세라핌)
#  1                                        Drama  aespa
#  2                                      사랑은 늘 도망가  임영웅
#  3                                      Do or Die  임영웅
#  4                                         모래 알갱이  임영웅
#  ..                                                ...
#  95                                  Dear. PLLI  PLAVE
#  96                                      사랑..그게 뭔데  지아
#  97                                    왜요 왜요 왜?  PLAVE
#  98  이쁜 여자가 좋더라 (Feat. Gist, Jayci yucca)  릴러말즈 (Le...
#  99                                       나의 목소리로  김호중
#
#                                         앨범          좋아요  듣기  담기    다운     뮤비
#  0                           Perfect Night  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  1              Drama - The 4th Mini Album  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  2                      신사와 아가씨 OST Part.2  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  3                               Do or Die  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  4                                  모래 알갱이  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  ..                                    ...          ...  ..  ..   ...    ...
#  95  ASTERUM : The Shape of Things to Come  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  96                              사랑..그게 뭔데  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  97  ASTERUM : The Shape of Things to Come  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  98                               인생은 한번이야  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#  99                                나의 목소리로  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#
#  [100 rows x 12 columns]]

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 1

# %%
df = tables[0]
df
# Out:
#     Unnamed: 0    순위      순위등락  앨범이미지 곡 상세가기  \
# 0          NaN    1위  순위 동일  0    NaN    곡정보
# 1          NaN    2위  순위 동일  0    NaN    곡정보
# 2          NaN    3위  단계 상승  1    NaN    곡정보
# 3          NaN    4위  단계 상승  2    NaN    곡정보
# 4          NaN    5위  단계 상승  3    NaN    곡정보
# ..         ...   ...       ...    ...    ...
# 95         NaN   96위     순위 진입    NaN    곡정보
# 96         NaN   97위  단계 하락  6    NaN    곡정보
# 97         NaN   98위     순위 진입    NaN    곡정보
# 98         NaN   99위  단계 하락  7    NaN    곡정보
# 99         NaN  100위     순위 진입    NaN    곡정보
#
#                                                   곡정보  \
# 0                   Perfect Night  LE SSERAFIM (르세라핌)
# 1                                        Drama  aespa
# 2                                      사랑은 늘 도망가  임영웅
# 3                                      Do or Die  임영웅
# 4                                         모래 알갱이  임영웅
# ..                                                ...
# 95                                  Dear. PLLI  PLAVE
# 96                                      사랑..그게 뭔데  지아
# 97                                    왜요 왜요 왜?  PLAVE
# 98  이쁜 여자가 좋더라 (Feat. Gist, Jayci yucca)  릴러말즈 (Le...
# 99                                       나의 목소리로  김호중
#
#                                        앨범          좋아요  듣기  담기    다운     뮤비
# 0                           Perfect Night  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 1              Drama - The 4th Mini Album  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 2                      신사와 아가씨 OST Part.2  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 3                               Do or Die  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 4                                  모래 알갱이  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# ..                                    ...          ...  ..  ..   ...    ...
# 95  ASTERUM : The Shape of Things to Come  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 96                              사랑..그게 뭔데  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 97  ASTERUM : The Shape of Things to Come  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 98                               인생은 한번이야  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 99                                나의 목소리로  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#
# [100 rows x 12 columns]

# %%
df.sample(10)
# Out:
#     Unnamed: 0    순위      순위등락  앨범이미지 곡 상세가기                            곡정보  \
# 64         NaN   65위  단계 하락  3    NaN    곡정보                  OMG  NewJeans
# 45         NaN   46위  단계 상승  6    NaN    곡정보                  Yes or No  정국
# 29         NaN   30위  순위 동일  0    NaN    곡정보        사막에서 꽃을 피우듯  우디 (Woody)
# 59         NaN   60위  단계 하락  2    NaN    곡정보              Kitsch  IVE (아이브)
# 50         NaN   51위  단계 하락  4    NaN    곡정보                   Snowman  Sia
# 90         NaN   91위  단계 하락  4    NaN    곡정보  Last Christmas  Ariana Grande
# 99         NaN  100위     순위 진입    NaN    곡정보                   나의 목소리로  김호중
# 91         NaN   92위     순위 진입    NaN    곡정보          I Just Love Ya  PLAVE
# 10         NaN   11위  단계 상승  2    NaN    곡정보                London Boy  임영웅
# 53         NaN   54위  단계 하락  1    NaN    곡정보              사랑하지 않아서 그랬어  임한별
#
#                                                 앨범          좋아요  듣기  담기    다운  \
# 64                                  NewJeans 'OMG'  좋아요  총건수  0  듣기  담기  다운로드
# 45                                          GOLDEN  좋아요  총건수  0  듣기  담기  다운로드
# 29                                     사막에서 꽃을 피우듯  좋아요  총건수  0  듣기  담기  다운로드
# 59                                        I've IVE  좋아요  총건수  0  듣기  담기  다운로드
# 50  Everyday Is Christmas (Snowman Deluxe Edition)  좋아요  총건수  0  듣기  담기  다운로드
# 90                                Christmas Kisses  좋아요  총건수  0  듣기  담기  다운로드
# 99                                         나의 목소리로  좋아요  총건수  0  듣기  담기  다운로드
# 91           ASTERUM : The Shape of Things to Come  좋아요  총건수  0  듣기  담기  다운로드
# 10                                        Polaroid  좋아요  총건수  0  듣기  담기  다운로드
# 53                                    사랑하지 않아서 그랬어  좋아요  총건수  0  듣기  담기  다운로드
#
#        뮤비
# 64  뮤직비디오
# 45  뮤직비디오
# 29  뮤직비디오
# 59  뮤직비디오
# 50  뮤직비디오
# 90  뮤직비디오
# 99  뮤직비디오
# 91  뮤직비디오
# 10  뮤직비디오
# 53  뮤직비디오
